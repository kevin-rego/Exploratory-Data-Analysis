# %% [markdown]
# <a href="https://colab.research.google.com/github/kevin-rego/Exploratory-Data-Analysis/blob/main/Detailed_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/cfb19.csv')

# %%
df #Initial structure of the data
# Out:
#                            Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0     Air Force (Mountain West)     13   11     2        51        881
# 1                   Akron (MAC)     12    0    12       130        725
# 2                 Alabama (SEC)     13   11     2         6        842
# 3    Appalachian St. (Sun Belt)     14   13     1        39        969
# 4              Arizona (Pac-12)     12    4     8        30        873
# ..                          ...    ...  ...   ...       ...        ...
# 125      West Virginia (Big 12)     12    5     7       119        788
# 126         Western Ky. (C-USA)     13    9     4        84        900
# 127         Western Mich. (MAC)     13    7     6        25        916
# 128         Wisconsin (Big Ten)     14   10     4        38        963
# 129     Wyoming (Mountain West)     13    8     5       106        831
#
#      Off.Yards  Off.Yards.Play  Off.TDs  Off.Yards.per.Game  ...  \
# ...

# %%
df.head(3)
# Out:
#                         Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0  Air Force (Mountain West)     13   11     2        51        881
# 1                Akron (MAC)     12    0    12       130        725
# 2              Alabama (SEC)     13   11     2         6        842
#
#    Off.Yards  Off.Yards.Play  Off.TDs  Off.Yards.per.Game  ...  \
# 0       5483            6.22       55               421.8  ...
# 1       2918            4.02       14               243.2  ...
# 2       6640            7.89       76               510.8  ...
#
#    Average.Time.of.Possession.per.Game  Turnover.Rank  Fumbles.Recovered  \
# 0                                34:28             78                  9
# 1                                26:29            128                  6
# 2                                29:59              3                 11
#
#    Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                      7              16            12
# ...

# %%
df.tail(7)
# Out:
#                         Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 123      Washington (Pac-12)     13    8     5        79        872
# 124  Washington St. (Pac-12)     13    6     7         7        920
# 125   West Virginia (Big 12)     12    5     7       119        788
# 126      Western Ky. (C-USA)     13    9     4        84        900
# 127      Western Mich. (MAC)     13    7     6        25        916
# 128      Wisconsin (Big Ten)     14   10     4        38        963
# 129  Wyoming (Mountain West)     13    8     5       106        831
#
#      Off.Yards  Off.Yards.Play  Off.TDs  Off.Yards.per.Game  ...  \
# 123       5086            5.83       48               391.2  ...
# 124       6568            7.14       62               505.2  ...
# 125       3863            4.90       28               321.9  ...
# 126       5041            5.60       38               387.8  ...
# 127       5794            6.33       56               445.7  ...
# ...

# %%
df.tail()
# Out:
#                         Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 125   West Virginia (Big 12)     12    5     7       119        788
# 126      Western Ky. (C-USA)     13    9     4        84        900
# 127      Western Mich. (MAC)     13    7     6        25        916
# 128      Wisconsin (Big Ten)     14   10     4        38        963
# 129  Wyoming (Mountain West)     13    8     5       106        831
#
#      Off.Yards  Off.Yards.Play  Off.TDs  Off.Yards.per.Game  ...  \
# 125       3863            4.90       28               321.9  ...
# 126       5041            5.60       38               387.8  ...
# 127       5794            6.33       56               445.7  ...
# 128       6065            6.30       56               433.2  ...
# 129       4562            5.49       38               350.9  ...
#
#      Average.Time.of.Possession.per.Game  Turnover.Rank  Fumbles.Recovered  \
# 125                                28:21            103                  6
# ...

# %%
df.dtypes
# Out:
# Team                             object
# Games                             int64
# Win                               int64
# Loss                              int64
# Off.Rank                          int64
#                                  ...
# Fumbles.Lost                      int64
# Interceptions.Thrown.y            int64
# Turnovers.Lost                    int64
# Turnover.Margin                   int64
# Avg.Turnover.Margin.per.Game    float64
# Length: 152, dtype: object

# %%
df.describe()
# Out:
#             Games         Win        Loss    Off.Rank    Off.Plays  \
# count  130.000000  130.000000  130.000000  130.000000   130.000000
# mean    12.784615    6.807692    5.976923   65.492308   885.953846
# std      0.757235    3.132961    2.504153   37.675326    76.366300
# min     12.000000    0.000000    0.000000    1.000000   717.000000
# 25%     12.000000    4.000000    5.000000   33.250000   841.000000
# 50%     13.000000    7.000000    6.000000   65.500000   881.000000
# 75%     13.000000    8.750000    8.000000   97.750000   936.500000
# max     15.000000   15.000000   12.000000  130.000000  1080.000000
#
#          Off.Yards  Off.Yards.Play     Off.TDs  Off.Yards.per.Game  \
# count   130.000000      130.000000  130.000000          130.000000
# mean   5167.530769        5.801308   44.307692          402.530769
# std     953.200372        0.722935   14.224036           59.017147
# min    2918.000000        4.020000   14.000000          243.200000
# ...

# %%
# describing stats of variables
df.describe().T
# Out:
#                               count        mean        std     min     25%  \
# Games                         130.0   12.784615   0.757235   12.00   12.00
# Win                           130.0    6.807692   3.132961    0.00    4.00
# Loss                          130.0    5.976923   2.504153    0.00    5.00
# Off.Rank                      130.0   65.492308  37.675326    1.00   33.25
# Off.Plays                     130.0  885.953846  76.366300  717.00  841.00
# ...                             ...         ...        ...     ...     ...
# Fumbles.Lost                  130.0    8.200000   2.963342    2.00    6.00
# Interceptions.Thrown.y        130.0    9.976923   3.652472    1.00    8.00
# Turnovers.Lost                130.0   18.176923   4.584208    6.00   15.00
# Turnover.Margin               130.0    0.323077   7.545434  -15.00   -5.00
# Avg.Turnover.Margin.per.Game  130.0    0.012385   0.586483   -1.25   -0.42
#
#                                 50%     75%     max
# ...

# %%
df.shape  #this represents shape of the df 130 rows and 147 columns.
# Out:
# (130, 152)

# %%
df.columns # column names
# Out:
# Index(['Team', 'Games', 'Win', 'Loss', 'Off.Rank', 'Off.Plays', 'Off.Yards',
#        'Off.Yards.Play', 'Off.TDs', 'Off.Yards.per.Game',
#        ...
#        'Average.Time.of.Possession.per.Game', 'Turnover.Rank',
#        'Fumbles.Recovered', 'Opponents.Intercepted', 'Turnovers.Gain',
#        'Fumbles.Lost', 'Interceptions.Thrown.y', 'Turnovers.Lost',
#        'Turnover.Margin', 'Avg.Turnover.Margin.per.Game'],
#       dtype='object', length=152)

# %%
df.info
# Out:
# <bound method DataFrame.info of                            Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0     Air Force (Mountain West)     13   11     2        51        881
# 1                   Akron (MAC)     12    0    12       130        725
# 2                 Alabama (SEC)     13   11     2         6        842
# 3    Appalachian St. (Sun Belt)     14   13     1        39        969
# 4              Arizona (Pac-12)     12    4     8        30        873
# ..                          ...    ...  ...   ...       ...        ...
# 125      West Virginia (Big 12)     12    5     7       119        788
# 126         Western Ky. (C-USA)     13    9     4        84        900
# 127         Western Mich. (MAC)     13    7     6        25        916
# 128         Wisconsin (Big Ten)     14   10     4        38        963
# 129     Wyoming (Mountain West)     13    8     5       106        831
#
#      Off.Yards  Off.Yards.Play  Off.TDs  Off.Yards.per.Game  ...  \
# ...

# %% [markdown]
# # **SORTING THE DATA**

# %%
df.sort_values(by=['Loss']).head(10)
# Out:
#                             Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 52                     LSU (SEC)     15   15     0         1       1080
# 21                 Clemson (ACC)     15   14     1         5       1075
# 3     Appalachian St. (Sun Belt)     14   13     1        39        969
# 77            Ohio St. (Big Ten)     14   13     1         4       1069
# 82               Oregon (Pac-12)     14   12     2        40        956
# 78             Oklahoma (Big 12)     14   12     2         3        946
# 30                 Florida (SEC)     13   11     2        45        865
# 12     Boise St. (Mountain West)     14   12     2        48        993
# 75  Notre Dame (FBS Independent)     13   11     2        43        886
# 65                    Navy (AAC)     13   11     2        19        877
#
#     Off.Yards  Off.Yards.Play  Off.TDs  Off.Yards.per.Game  ...  \
# 52       8526            7.89       93               568.4  ...
# ...

# %%
df.sort_values(by=['Win'],ascending=False).head(8)
# Out:
#                           Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 52                   LSU (SEC)     15   15     0         1       1080
# 21               Clemson (ACC)     15   14     1         5       1075
# 3   Appalachian St. (Sun Belt)     14   13     1        39        969
# 77          Ohio St. (Big Ten)     14   13     1         4       1069
# 12   Boise St. (Mountain West)     14   12     2        48        993
# 82             Oregon (Pac-12)     14   12     2        40        956
# 78           Oklahoma (Big 12)     14   12     2         3        946
# 34               Georgia (SEC)     14   12     2        61        940
#
#     Off.Yards  Off.Yards.Play  Off.TDs  Off.Yards.per.Game  ...  \
# 52       8526            7.89       93               568.4  ...
# 21       7931            7.38       85               528.7  ...
# 3        6064            6.26       65               433.1  ...
# 77       7419            6.94       87               529.9  ...
# ...

# %%
df.sort_values(by=['Win'],ascending=False,inplace=True)

# %%
# Counting the occurences of variables
df.Games.value_counts()
# Out:
# 13    59
# 12    51
# 14    17
# 15     3
# Name: Games, dtype: int64

# %%
df.Win.value_counts()
# Out:
# 8     23
# 4     18
# 7     14
# 5     14
# 11    12
# 6     10
# 3      8
# 10     7
# 2      6
# 12     5
# 9      5
# 1      3
# 13     2
# 15     1
# 14     1
# 0      1
# Name: Win, dtype: int64

# %%
# Using .nunique() to count number of unique values that occur in dataset
df.nunique()
# Out:
# Team                            130
# Games                             4
# Win                              16
# Loss                             13
# Off.Rank                        129
#                                ...
# Fumbles.Lost                     15
# Interceptions.Thrown.y           19
# Turnovers.Lost                   23
# Turnover.Margin                  33
# Avg.Turnover.Margin.per.Game     58
# Length: 152, dtype: int64

# %%
df.dtypes
team = df['Team']

# %% [markdown]
#  It is converting the values of the 'Win' column in a Pandas DataFrame (df) from its current data type to a numeric data type using the pd.to_numeric function. The "errors='coerce'" argument means that any non-numeric values in the 'Win' column will be set to NaN (Not a Number) instead of raising an error.

# %%
df[['Win']] = df[['Win']].apply(pd.to_numeric, errors='coerce')

# %%
cor = df.corr()

# %%
#Correlation with respect to Win variable and filtering out variables with less correlation.
columns = cor[cor["Win"]>0.75]['Win']
columns_list = columns.index
columns_list
# Out:
# Index(['Games', 'Win', 'Off.Yards', 'Off.TDs', 'Redzone.Scores', 'Touchdowns',
#        'PAT', 'Total.Points', 'Points.Per.Game'],
#       dtype='object')

# %%
df1 = pd.DataFrame(df, columns=columns_list)

# %%
df2 = df1.drop('Games', axis= 1)  
df2['Team'] = team

# %%
#create the correlation matrix heat map
plt.figure(figsize=(14,12))

sns.heatmap(df2.corr(),linewidths=.1,cmap="YlGnBu", annot=True)

plt.yticks(rotation=0);

# %%
#pair plots
g = sns.pairplot(df2)

# %%
# Plot colored by continent for years 2000-2007
sns.pairplot(df2[df2['Win'] > 5], 
             vars = ['Off.Yards', 'Touchdowns', 'PAT'], diag_kind = 'kde', 
             plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'},
             size = 4);
# Title 
plt.suptitle('Pair Plot of influential factors for winning', 
             size = 28);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### **EDA PART-1**

# %% [markdown]
# **Univariate Analysis**

# %%
sns.distplot(df['Games'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Win'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(df['Win'], df['Games'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#kind : { "scatter" | "reg" | "resid" | "kde" | "hex" }
sns.jointplot(df['Win'], df['Games'], kind = 'hex')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(df[['Off.Rank','Off.Plays','Off.Yards']]) #Off.Rank	Off.Plays	Off.Yards

# %% [markdown]
# **Bivariate Data Analysis**
#
# A scatterplot simply plots the x and y values of the data points and can result in a lot of overlap of points if the data is dense. A swarm plot adjusts the positions of the points to reduce the amount of overlap and make it easier to see the distribution of the data. Instead of plotting each point at its exact x and y value, a swarm plot "swarms" the points around their x and y values in such a way that they don't overlap as much. This results in a plot that is easier to read and provides a clearer picture of the distribution of the data.

# %%
sns.swarmplot(df['Win'], df['Off.Plays'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:1296: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df['Win'], df['Off.Plays'], hue=df['Games'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['Games'], df['Win'], hue=df['Loss'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(df['Win'], df['Off.Plays'], hue=df['Games'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df['Win'], hue=df['Games'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pointplot(df['Off.Yards'], df['Win'], hue=df['Games'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot(x='Win', y ='Off.Plays', data= df, hue='Games')

# %% [markdown]
# ### **EDA Part-3**

# %%
sns.stripplot(df['Win'],df['Games'], jitter=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#A strip plot is a scatter plot where one variable is categorical. In this code, the categorical variable
sns.regplot(x='Win', y='Off.Yards', data = df[df['Loss'] < 10])
